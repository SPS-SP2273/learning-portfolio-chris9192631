# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Functions (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 User-defined functions

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 import matplotlib
#       3 import random
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
import random

# %%
# !conda install matplotlib -c conda-forge -y
# Out:
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\chris\miniconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.1.0               |       h2466b09_3          20 KB  conda-forge
#     brotli-bin-1.1.0           |       h2466b09_3          21 KB  conda-forge
#     contourpy-1.3.3            |  py313hf069bd2_1         219 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     fonttools-4.59.2           |  py313hd650c13_0         2.4 MB  conda-forge
#     kiwisolver-1.4.9           |  py313h1a38498_0          72 KB  conda-forge
#     libbrotlicommon-1.1.0      |       h2466b09_3          70 KB  conda-forge
# ...

# %%
m,c = 3,4

def my_line(x,y):
    x_values1 = [x for x in range(10)]
    y_values1= [m*x_value + c + random.random() for x_value in x_values1()]
    return(x_values1, y_values1)




#try numpy.savetext , which saves your x and y values as (can save as a f string) as a seprata text file in the same folder
#can use write_data also instead of numpy packagae


#if you want to plot multiple lines, you can just define the m and c outside of the equation 

# If you display a function, it will show up as arrays 
#If you try to display the variable of the function in the terminal, you cannot do so because it only exists within the function (scope)

# %% [markdown]
# ## 1.1 Named Functions

# %% [markdown]
# ### Named functions that return

# %%
def greeting(name):
    if name == 'Batman':
        return 'Hello Batman! So, nice to meet you!'
    else:
        return f'Hello {name}!'
# Your code here

# %% [markdown]
# ### Named functions that don’t return

# %%
# Your code here

# %% [markdown]
# ## 1.2 Anonymous functions

# %% [markdown]
# ## 1.3 Optional arguments

# %% [markdown]
# ## 1.4 The importance of functions?

# %% [markdown]
# ### An argument for functions

# %%
# Your code here

# %% [markdown]
# ### A word of caution

# %%
# Your code here
